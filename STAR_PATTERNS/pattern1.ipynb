# %% [markdown]
# *
# **
# ***
# ****
# *****

# %%
n = 6 
for i in range(n):
    for j in range(0,i):
        print("*" , end = " ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# * * * *
# * * *
# * *
# *

# %%
n = 6
for i in range(n-2,-1,-1):
    for j in range(0,i):
        print(f"*" , end = " ")
    
    print()
# Out:
# * * * *
# * * *
# * *
# *

# %% [markdown]
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n = 6 

for i in range(n):
    for j in range(0,i):
        print("*" , end = " ")
    print()
    
for i in range(n-2,-1,-1):
    for j in range(0,i):
        print(f"*" , end = " ")
    
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
