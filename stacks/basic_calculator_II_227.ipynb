# %% [markdown]
# ### Basic Calculator II  : Leetcode : 227
#
# Example 1:
#
# Input: s = "3+2*2"
# Output: 7
#
# Example 2:
#
# Input: s = " 3/2 "
# Output: 1
#
# Example 3:
#
# Input: s = " 3+5 / 2 "
# Output: 5
