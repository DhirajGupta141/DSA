# %%
a = [4,5,6,2,1]

# %%
# len 
len(a)
# Out:
# 5

# %%
# sorting 

a.sort()
a
# Out:
# [1, 2, 4, 5, 6]

# %%
# min and max 

print(f"Min in the array is {min(a)} and max is {max(a)}")
# Out:
# Min in the array is 1 and max is 6

# %%
# sorted array 

a = sorted(a)
a
# Out:
# [1, 2, 4, 5, 6]

# %% [markdown]
# ### array.reverse()

# %%
a = [4,10,1,20]
a.reverse()
a
# Out:
# [20, 1, 10, 4]

# %% [markdown]
# ### Reverse Array Using Trick in Python

# %%
a = [20,10,5,0,100]
a
# Out:
# [20, 10, 5, 0, 100]

# %%
a[::-1]
# Out:
# [100, 0, 5, 10, 20]
