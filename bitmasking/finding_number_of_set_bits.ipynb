# %% [markdown]
# ### Finding Number of set bits of a given integer

# %%
n = 3
count = 0 
while n != 0:
    n = n & (n-1)
    count +=1 

print(f"Number of Set bits of the integer {n} is {count}")
# Out:
# Number of Set bits of the integer 0 is 2
