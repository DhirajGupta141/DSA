# %% [markdown]
# #### Reverse A Singly LinkedList

# %% [markdown]
# Whats we do ?
#
# Because at every step, you are doing:
#
# 1. Take 1 node ( Hold the curr.next )
#
# 2. Reverse its link ( reverse the curr which would be hold by the prev)
#
# 3. Move forward ( Both prev and current)
#
# You NEVER lose the rest of the list because you always store the next node first.

# %%
# Definition for singly-linked list.
from typing import Optional

class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
class Solution:
    def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:

        curr_node = head 
        prev_node = None

        while curr_node:   # we cannot write WHILE curr_node.next: as we need to reverse the last element 
            next_node = curr_node.next  # 1. hold next node 
            curr_node.next = prev_node # 2. reverse poiter 
            prev_node = curr_node  # 3. move previous forrward as we have reversed the pointer 
            curr_node = next_node # 4. move current forward as we have reversed the pointer
        
        return prev_node


# Input : 
# 1-> 2-> 3-> 4-> None 

# Output :
# None <- 1 <- 2 <- 3 <- 4
